# %%
pwd
# Out:
# 'C:\\Users\\gokul\\Desktop\\Univariate analysis'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sweetviz as sz

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
datae = pd.read_excel('Sample - Superstore.xls')

# %%
datae.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
for col in datae.columns:
    print(datae[col].dtype, datae[col].unique(), datae[col].value_counts())
# Out:
# int64 [   1    2    3 ... 9992 9993 9994] 2047    1
# 7473    1
# 3387    1
# 1338    1
# 7481    1
#        ..
# 2716    1
# 8857    1
# 4759    1
# 6806    1
# 2049    1
# Name: Row ID, Length: 9994, dtype: int64
# object ['CA-2016-152156' 'CA-2016-138688' 'US-2015-108966' ... 'CA-2014-110422'
#  'CA-2017-121258' 'CA-2017-119914'] CA-2017-100111    14
# CA-2017-157987    12
# CA-2016-165330    11
# US-2016-108504    11
# CA-2015-131338    10
#                   ..
# CA-2016-140928     1
# CA-2015-105361     1
# US-2016-147991     1
# US-2014-107405     1
# CA-2017-128629     1
# Name: Order ID, Length: 5009, dtype: int64
# datetime64[ns] ['2016-11-08T00:00:00.000000000' '2016-06-12T00:00:00.000000000'
#  '2015-10-11T00:00:00.000000000' ... '2016-06-03T00:00:00.000000000'
#  '2015-04-12T00:00:00.000000000' '2014-01-21T00:00:00.000000000'] 2016-09-05    38
# 2017-09-02    36
# 2016-11-10    35
# 2017-12-01    34
# 2017-12-02    34
#               ..
# 2015-01-26     1
# ...

# %%
datae.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df1 = datae.select_dtypes([np.int64, np.float64])

for i, col in enumerate(df1.columns):
    plt.figure(i)
    sns.boxplot(y = col, data = df1)

# %%
  df2 = datae[['Product Name', 'Sub-Category', 'Category', 'Region', 'State', 'City', 'Country', 'Segment', 'Ship Mode']]
for i,col in enumerate(df2.columns):
  plt.figure(i)
  fig_dims = (20, 10)
  fig, ax = plt.subplots(figsize=fig_dims)
  sns.countplot(x = col, data = df2, ax = ax)
    #sns.pairplot(frame[num_cols],size=2)
# Out:
#   File "<ipython-input-11-b0bcc42e3eaa>", line 3
#     plt.figure(i)
#     ^
# IndentationError: expected an indented block

# %%
#report = sz.analyze([datae, "Data"], target_feat = 'Profit')

# %%
#report.show_html('Sales.html')

# %%
dataen = datae[['Order Date','Sales']]
dataen
# Out:
#      Order Date     Sales
# 0    2016-11-08  261.9600
# 1    2016-11-08  731.9400
# 2    2016-06-12   14.6200
# 3    2015-10-11  957.5775
# 4    2015-10-11   22.3680
# ...         ...       ...
# 9989 2014-01-21   25.2480
# 9990 2017-02-26   91.9600
# 9991 2017-02-26  258.5760
# 9992 2017-02-26   29.6000
# 9993 2017-05-04  243.1600
#
# [9994 rows x 2 columns]

# %%
#ordering date ascending wise to form a series
dataen = dataen.sort_values('Order Date')

dataen.head()
# Out:
#      Order Date    Sales
# 7980 2014-01-03   16.448
# 739  2014-01-04   11.784
# 740  2014-01-04  272.736
# 741  2014-01-04    3.540
# 1759 2014-01-05   19.536

# %%
dataen['Order Date'].min()
dataen['Order Date'].max()
# Out:
# Timestamp('2014-01-03 00:00:00')
# Timestamp('2017-12-30 00:00:00')

# %%
dataen.groupby('Order Date')['Sales'].sum().reset_index()
dataen
# Out:
#      Order Date      Sales
# 0    2014-01-03    16.4480
# 1    2014-01-04   288.0600
# 2    2014-01-05    19.5360
# 3    2014-01-06  4407.1000
# 4    2014-01-07    87.1580
# ...         ...        ...
# 1232 2017-12-26   814.5940
# 1233 2017-12-27   177.6360
# 1234 2017-12-28  1657.3508
# 1235 2017-12-29  2915.5340
# 1236 2017-12-30   713.7900
#
# [1237 rows x 2 columns]
#      Order Date    Sales
# 7980 2014-01-03   16.448
# 739  2014-01-04   11.784
# 740  2014-01-04  272.736
# 741  2014-01-04    3.540
# 1759 2014-01-05   19.536
# ...         ...      ...
# 5091 2017-12-30    3.024
# 908  2017-12-30   52.776
# 907  2017-12-30   90.930
# 1296 2017-12-30   13.904
# 906  2017-12-30  323.136
#
# [9994 rows x 2 columns]

# %%
#setting order date as index
dataen
dataen = dataen.set_index('Order Date')
dataen.index
# Out:
#      Order Date    Sales
# 7980 2014-01-03   16.448
# 739  2014-01-04   11.784
# 740  2014-01-04  272.736
# 741  2014-01-04    3.540
# 1759 2014-01-05   19.536
# ...         ...      ...
# 5091 2017-12-30    3.024
# 908  2017-12-30   52.776
# 907  2017-12-30   90.930
# 1296 2017-12-30   13.904
# 906  2017-12-30  323.136
#
# [9994 rows x 2 columns]
# DatetimeIndex(['2014-01-03', '2014-01-04', '2014-01-04', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-06', '2014-01-06',
#                '2014-01-06', '2014-01-06',
#                ...
#                '2017-12-29', '2017-12-29', '2017-12-29', '2017-12-30',
#                '2017-12-30', '2017-12-30', '2017-12-30', '2017-12-30',
#                '2017-12-30', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=9994, freq=None)

# %%
#average the daily sales for each month
res1 = dataen['Sales'].resample('MS').mean()
res1['2014':]
# Out:
# Order Date
# 2014-01-01    180.213861
# 2014-02-01     98.258522
# 2014-03-01    354.719803
# 2014-04-01    209.595148
# 2014-05-01    193.838418
# 2014-06-01    256.260204
# 2014-07-01    237.387364
# 2014-08-01    182.414827
# 2014-09-01    305.139369
# 2014-10-01    197.820082
# 2014-11-01    247.260115
# 2014-12-01    250.164103
# 2015-01-01    313.346131
# 2015-02-01    186.740797
# 2015-03-01    280.625014
# 2015-04-01    213.720053
# 2015-05-01    206.381414
# 2015-06-01    179.690522
# 2015-07-01    205.466607
# 2015-08-01    232.064982
# 2015-09-01    220.463884
# 2015-10-01    189.186286
# 2015-11-01    234.483221
# 2015-12-01    237.087092
# 2016-01-01    208.342596
# 2016-02-01    276.853193
# 2016-03-01    317.275307
# 2016-04-01    227.941406
# 2016-05-01    253.278791
# 2016-06-01    202.736352
# 2016-07-01    195.333149
# 2016-08-01    176.791899
# 2016-09-01    202.231474
# 2016-10-01    304.529311
# 2016-11-01    214.626935
# 2016-12-01    275.565463
# ...

# %% [markdown]
# # Data visualization

# %%
res1.plot(figsize = (20,10))
plt.show
# Out:
# <AxesSubplot:xlabel='Order Date'>
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Time-series decompositon
#
# It allows us to decompose our time series into three distinct components
#
# ->Trend
#
# ->Seasonality
#
# ->Noise

# %%
import statsmodels.api as sm
decompo = sm.tsa.seasonal_decompose(res1, model = 'additive')
fig = decompo.plot()
plt.show()

# %% [markdown]
# We can say that the sales of the company...,
# 1) The trend is increasing so the sales of the company is growing periodically
#
# 2) The seasonal index shows the sales every second half of the year the sales is incresed seasonally

# %% [markdown]
# # Forecasting with ARIMA model

# %%
p = d = q = range(0, 2)
model = sm.tsa.statespace.SARIMAX(res1, order = (1, 1, 1),
                                  seasonal_order = (1, 1, 0, 12)
                                 )
result = model.fit()
print(result.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0913      0.286     -0.319      0.750      -0.651       0.469
# ma.L1         -0.9982      9.598     -0.104      0.917     -19.810      17.813
# ar.S.L12      -0.5598      0.156     -3.594      0.000      -0.865      -0.254
# sigma2      2799.1393   2.67e+04      0.105      0.917   -4.95e+04    5.51e+04
# ...

# %%
prediction = result.get_prediction(start = pd.to_datetime('2017-01-01'), dynamic = False)
prediction_ci = prediction.conf_int()
prediction_ci
# Out:
#             lower Sales  upper Sales
# Order Date
# 2017-01-01   166.949828   380.855436
# 2017-02-01   128.374776   341.873715
# 2017-03-01   201.126553   414.265416
# 2017-04-01   122.357190   335.174995
# 2017-05-01   126.153430   338.683180
# 2017-06-01    87.013281   299.283140
# 2017-07-01    92.953015   304.987211
# 2017-08-01   102.323359   314.142882
# 2017-09-01   103.098059   314.721217
# 2017-10-01   139.372347   350.815201
# 2017-11-01   122.030717   333.307438
# 2017-12-01   150.521235   361.644384

# %%
ax = res1['2014':].plot(label = 'observed')
prediction.predicted_mean.plot(ax = ax, label = 'One-step ahead Forecast', alpha = 0.7, figsize = (14, 7))
ax.fill_between(prediction_ci.index, prediction_ci.iloc[:, 0], prediction_ci.iloc[:, 1], color = 'k', alpha = 0.2)
ax.set_xlabel("Date")
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()
# Out:
# <AxesSubplot:xlabel='Order Date'>
# Text(0.5, 0, 'Date')
# Text(0, 0.5, 'Furniture Sales')

# %%
y_hat = prediction.predicted_mean
y_truth = res1['2017-01-01':]

mse = ((y_hat - y_truth) ** 2).mean()
rmse = np.sqrt(mse)
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2069.58
# The Root Mean Squared Error of our forecasts is 45.49

# %%
# forcasting for out of sample data
pred_uc = result.get_forecast(steps = 100)
pred_ci = pred_uc.conf_int()

ax = res1.plot(label = 'observed', figsize = (14, 7))
pred_uc.predicted_mean.plot(ax = ax, label = 'forecast')
ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color = 'k', alpha = 0.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')

plt.legend()
plt.show()
# Out:
# <AxesSubplot:xlabel='Order Date'>
# Text(0.5, 0, 'Date')
# Text(0, 0.5, 'Furniture Sales')

# %% [markdown]
# Thus we predicted the averae sales for the future years
